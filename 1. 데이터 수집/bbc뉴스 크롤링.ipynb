# %% [markdown]
# ## BBC뉴스 헤드라인 스크랩

# %%
import urllib.request as ure
from bs4 import BeautifulSoup as bs

news='https://www.bbc.com/'
soup=bs(ure.urlopen(news).read(), 'html.parser')

#공통점 찾아야함, 링크를 hero에 저장
hero=soup.find_all('a', {"class":"block-link__overlay-link"})

# %%
for i in soup.find_all('a', {"class":"media__link"}):
    print(i.text)
# Out:
#                                                                     Russia allows some evacuations but Mariupol attacks reported
#
#                                                                     Chernobyl workers' ordeal under Russian guard
#
#                                                                     False claims that Ukraine war is a hoax go viral
#
#                                                                     Should in-office workers be paid more?
#
#                                                                     The dangers in modern kitchens
#
#                                                                     Russia says it may cut gas supplies if oil blocked
#
#                                                                     Zelensky: I'm not hiding, I'm not afraid
#
#                                                                     Russian general killed near Kharkiv, says Ukraine
#
# ...

# %% [markdown]
# ## 오류의 이유

# %%
# href를 했을 때 htts://www.bbc.com/이 붙어 링크 형식으로 불러와야하는데 html형식 자체가 그렇게 저장하고 있지 못하다보니 오류 발생...
for i in soup.find_all('a',{"class":"media__link"}):
    print(i.get('href'))
# Out:
# /news/live/world-europe-60657155
# https://www.bbc.com/news/world-europe-60638949
# https://www.bbc.com/news/60589965
# https://www.bbc.com/worklife/article/20220307-should-in-office-workers-be-paid-more
# https://www.bbc.com/future/article/20220228-the-hidden-dangers-lurking-in-your-kitchen
# /news/business-60656673
# /news/world-europe-60659029
# /news/world-europe-60659185
# /sport/football/60656543
# /sport/winter-sports/60659645
# /sport/cricket/60658487
# /news/world-australia-60656717
# /news/world-asia-60598235
# /news/world-asia-60643446
# /news/world-asia-india-60647656
# https://www.bbc.com/culture/article/20220307-janet-sobel-the-woman-written-out-of-history
# https://www.bbc.com/travel/article/20220307-romes-new-museum-dedicated-to-cooking
# https://www.bbc.com/worklife/article/20220302-why-uncommon-baby-names-are-surging
# https://www.bbc.com/future/article/20220302-the-adverts-that-were-banned-for-misleading-climate-claims
# https://www.bbc.com/news/world-60653099
# ...

# %%
rows = []
for i in range(len(hero)):
    # 타이틀, url, text 추출
    # 타이틀 가져오기
    herotitle = hero[i].text
    # url 가져오기
    herourl = "https://www.bbc.com/" + hero[i].get('href')
    # 가져온 url을 html로 해석함
    soup2=bs(ure.urlopen(herourl).read(), 'html.parser')
    # text 추출
    txt=""
    for j in soup2.find_all('p'):
        txt=txt+j.text
    rows.append({'Title': herotitle, 'URL':herourl, 'Text':txt})
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_18844/1373548394.py in <module>
#       7     herourl = "https://www.bbc.com/" + hero[i].get('href')
#       8     # 가져온 url을 html로 해석함
# ----> 9     soup2=bs(ure.urlopen(herourl).read(), 'html.parser')
#      10     # text 추출
#      11     txt=""
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
# ...

# %%
import pandas as pd
df = pd.DataFrame(rows, columns=['Title', 'URL', 'Text'])
